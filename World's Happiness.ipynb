# %% [markdown]
# # Context
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %% [markdown]
# # Content
# The happiness scores and rankings use data from the Gallup World Poll. The scores are based on answers to the main life evaluation question asked in the poll. This question, known as the Cantril ladder, asks respondents to think of a ladder with the best possible life for them being a 10 and the worst possible life being a 0 and to rate their own current lives on that scale. The scores are from nationally representative samples for the years 2013-2016 and use the Gallup weights to make the estimates representative. The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity – contribute to making life evaluations higher in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors. They have no impact on the total score reported for each country, but they do explain why some countries rank higher than others.

# %% [markdown]
# # The Focus of The Study
#
# The focus of the study is to observe the differences between countries with the highest and lowest happiness scores. In my observations, I observed that the happiness scores of countries depend on different criteria in the happiest and unhappiest countries. Let's start the analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
df1 = pd.read_csv('2015.csv')
df2 = pd.read_csv('2016.csv')
df3 = pd.read_csv('2017.csv')
df4 = pd.read_csv('2018.csv')
df5 = pd.read_csv('2019.csv')

# %%
#We must add Year info to our datasets to make more clear.
def year(data,i):
    Year = []
    for column in range(0,len(data)):
        Year.append(i)
        data['Year'] = pd.DataFrame(Year)

#This function changes name of the columns        
def rename_column(data,column,new_name):
    data[new_name] = data[column].rename(new_name)
    data.drop(column,axis = 1,inplace = True)
#This function drops columns.
def dropper(data,column):
    data.drop(column,axis = 1,inplace = True)

# %%
year(df1,2015)
year(df2,2016)
year(df3,2017)
year(df4,2018)
year(df5,2019)

# %%
df_2015 = df1
df_2016 = df2
df_2017 = df3
df_2018 = df4
df_2019 = df5

# %%
rename_column(df_2015,'Happiness Score','Score')
rename_column(df_2016,'Happiness Score','Score')
rename_column(df_2017,'Happiness.Score','Score')

# %% [markdown]
# We should drop ranking columns. We can reach that information by Happiness Score column.

# %%
dropper(df_2015,'Happiness Rank')
dropper(df_2016,'Happiness Rank')
dropper(df_2017,'Happiness.Rank')
dropper(df_2018,'Overall rank')
dropper(df_2019,'Overall rank')

# %% [markdown]
# We want to see all columns informations.

# %%
print(df_2015.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Standard Error                 158 non-null    float64
#  3   Economy (GDP per Capita)       158 non-null    float64
#  4   Family                         158 non-null    float64
#  5   Health (Life Expectancy)       158 non-null    float64
#  6   Freedom                        158 non-null    float64
#  7   Trust (Government Corruption)  158 non-null    float64
#  8   Generosity                     158 non-null    float64
#  9   Dystopia Residual              158 non-null    float64
#  10  Year                           158 non-null    int64
#  11  Score                          158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB
# None

# %%
print(df_2016.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Lower Confidence Interval      157 non-null    float64
#  3   Upper Confidence Interval      157 non-null    float64
#  4   Economy (GDP per Capita)       157 non-null    float64
#  5   Family                         157 non-null    float64
#  6   Health (Life Expectancy)       157 non-null    float64
#  7   Freedom                        157 non-null    float64
#  8   Trust (Government Corruption)  157 non-null    float64
#  9   Generosity                     157 non-null    float64
#  10  Dystopia Residual              157 non-null    float64
#  11  Year                           157 non-null    int64
#  12  Score                          157 non-null    float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 16.1+ KB
# None

# %%
print(df_2017.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Whisker.high                   155 non-null    float64
#  2   Whisker.low                    155 non-null    float64
#  3   Economy..GDP.per.Capita.       155 non-null    float64
#  4   Family                         155 non-null    float64
#  5   Health..Life.Expectancy.       155 non-null    float64
#  6   Freedom                        155 non-null    float64
#  7   Generosity                     155 non-null    float64
#  8   Trust..Government.Corruption.  155 non-null    float64
#  9   Dystopia.Residual              155 non-null    float64
#  10  Year                           155 non-null    int64
#  11  Score                          155 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 14.7+ KB
# None

# %%
print(df_2018.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country or region             156 non-null    object
#  1   Score                         156 non-null    float64
#  2   GDP per capita                156 non-null    float64
#  3   Social support                156 non-null    float64
#  4   Healthy life expectancy       156 non-null    float64
#  5   Freedom to make life choices  156 non-null    float64
#  6   Generosity                    156 non-null    float64
#  7   Perceptions of corruption     155 non-null    float64
#  8   Year                          156 non-null    int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB
# None

# %%
print(df_2019.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country or region             156 non-null    object
#  1   Score                         156 non-null    float64
#  2   GDP per capita                156 non-null    float64
#  3   Social support                156 non-null    float64
#  4   Healthy life expectancy       156 non-null    float64
#  5   Freedom to make life choices  156 non-null    float64
#  6   Generosity                    156 non-null    float64
#  7   Perceptions of corruption     156 non-null    float64
#  8   Year                          156 non-null    int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB
# None

# %% [markdown]
# We need some visualizations to understand our datasets better.

# %% [markdown]
# We have 5 different datasets and we need to look at the same values year by year to understand differences between values. So we need a couple of functions.

# %%
factors_of_2015_all = []
def heatmap_corr(data,corr_with_score):
    plt.figure(figsize = (12,6))
    sns.heatmap(data.corr(),annot = True,cmap = 'icefire_r')
    plt.show()            
    print(""" These are the correlations for happiness score of all countries in {}\n      
{}
        
""".format(data['Year'].iloc[1],pd.DataFrame(data.corr()[corr_with_score].sort_values(ascending = False)[1:])))
    
def heatmap_corr_head(data,corr_with_score):
    plt.figure(figsize = (12,6))
    sns.heatmap(data.head().corr(),annot = True,cmap = 'Set3')
    plt.show()
    print(""" These are the correlations for countries with highest happiness score in {}\n      
{}
        
""".format(data['Year'].iloc[1],pd.DataFrame(data.head().corr()[corr_with_score].sort_values(ascending = False)[1:])))

def heatmap_corr_tail(data,corr_with_score):
    plt.figure(figsize = (12,6))
    sns.heatmap(data.tail().corr(),annot = True,cmap = 'ocean_r')
    plt.show()
    print(""" These are the correlations for countries with lowest happiness score {}\n
    {}
    """.format(data['Year'].iloc[1],pd.DataFrame(data.tail().corr()[corr_with_score].sort_values(ascending = False)[1:])))

# %%
heatmap_corr(df_2015,'Score')
heatmap_corr_head(df_2015,'Score')
heatmap_corr_tail(df_2015,'Score')
# Out:
#  These are the correlations for happiness score of all countries in 2015
#
#                                   Score
# Economy (GDP per Capita)       0.780966
# Family                         0.740605
# Health (Life Expectancy)       0.724200
# Freedom                        0.568211
# Dystopia Residual              0.530474
# Trust (Government Corruption)  0.395199
# Generosity                     0.180319
# Standard Error                -0.177254
# Year                                NaN
#  These are the correlations for countries with highest happiness score in 2015
#
#                                   Score
# Family                         0.608195
# Dystopia Residual              0.533683
# Health (Life Expectancy)       0.470024
# Freedom                        0.402260
# Standard Error                 0.245685
# Economy (GDP per Capita)       0.198748
# Trust (Government Corruption) -0.030551
# Generosity                    -0.648443
# Year                                NaN
#  These are the correlations for countries with lowest happiness score 2015
#
#                                       Score
# Freedom                        0.798165
# Family                         0.715794
# Trust (Government Corruption)  0.658381
# Health (Life Expectancy)       0.117187
# Economy (GDP per Capita)       0.056087
# Generosity                    -0.097526
# Dystopia Residual             -0.309532
# Standard Error                -0.856436
# Year                                NaN

# %%
heatmap_corr(df_2016,'Score')
heatmap_corr_head(df_2016,'Score')
heatmap_corr_tail(df_2016,'Score')
# Out:
#  These are the correlations for happiness score of all countries in 2016
#
#                                   Score
# Lower Confidence Interval      0.999485
# Upper Confidence Interval      0.999474
# Economy (GDP per Capita)       0.790322
# Health (Life Expectancy)       0.765384
# Family                         0.739252
# Freedom                        0.566827
# Dystopia Residual              0.543738
# Trust (Government Corruption)  0.402032
# Generosity                     0.156848
# Year                                NaN
#  These are the correlations for countries with highest happiness score in 2016
#
#                                   Score
# Upper Confidence Interval      0.789529
# Lower Confidence Interval      0.617832
# Generosity                     0.520220
# Family                         0.439906
# Economy (GDP per Capita)       0.418717
# Freedom                        0.360202
# Health (Life Expectancy)       0.152178
# Trust (Government Corruption) -0.103522
# Dystopia Residual             -0.530440
# Year                                NaN
#  These are the correlations for countries with lowest happiness score 2016
#
#                                       Score
# Lower Confidence Interval      0.998918
# Upper Confidence Interval      0.997874
# Freedom                        0.854697
# Dystopia Residual              0.382701
# Economy (GDP per Capita)       0.169474
# Generosity                    -0.260679
# Health (Life Expectancy)      -0.273865
# Trust (Government Corruption) -0.515402
# Family                        -0.706336
# Year                                NaN

# %%
heatmap_corr(df_2017,'Score')
heatmap_corr_head(df_2017,'Score')
heatmap_corr_tail(df_2017,'Score')
# Out:
#  These are the correlations for happiness score of all countries in 2017
#
#                                   Score
# Whisker.low                    0.999520
# Whisker.high                   0.999497
# Economy..GDP.per.Capita.       0.812469
# Health..Life.Expectancy.       0.781951
# Family                         0.752737
# Freedom                        0.570137
# Dystopia.Residual              0.475355
# Trust..Government.Corruption.  0.429080
# Generosity                     0.155256
# Year                                NaN
#  These are the correlations for countries with highest happiness score in 2017
#
#                                   Score
# Freedom                        0.916261
# Whisker.low                    0.734475
# Whisker.high                   0.685552
# Economy..GDP.per.Capita.       0.640471
# Generosity                     0.524315
# Family                         0.038970
# Trust..Government.Corruption. -0.130083
# Health..Life.Expectancy.      -0.435666
# Dystopia.Residual             -0.757465
# Year                                NaN
#  These are the correlations for countries with lowest happiness score 2017
#
#                                       Score
# Whisker.low                    0.992117
# Whisker.high                   0.989984
# Health..Life.Expectancy.       0.940714
# Economy..GDP.per.Capita.       0.879816
# Family                         0.667380
# Trust..Government.Corruption.  0.582425
# Generosity                     0.537028
# Freedom                        0.371280
# Dystopia.Residual             -0.933386
# Year                                NaN

# %%
heatmap_corr(df_2018,'Score')
heatmap_corr_head(df_2018,'Score')
heatmap_corr_tail(df_2018,'Score')
# Out:
#  These are the correlations for happiness score of all countries in 2018
#
#                                  Score
# GDP per capita                0.802124
# Healthy life expectancy       0.775814
# Social support                0.745760
# Freedom to make life choices  0.544280
# Perceptions of corruption     0.405292
# Generosity                    0.135825
# Year                               NaN
#  These are the correlations for countries with highest happiness score in 2018
#
#                                  Score
# Freedom to make life choices  0.708906
# Perceptions of corruption     0.545073
# Social support               -0.069509
# GDP per capita               -0.219422
# Generosity                   -0.625953
# Healthy life expectancy      -0.853590
# Year                               NaN
#  These are the correlations for countries with lowest happiness score 2018
#
#                                      Score
# GDP per capita                0.884162
# Healthy life expectancy       0.705925
# Social support                0.581995
# Freedom to make life choices  0.513644
# Perceptions of corruption     0.319814
# Generosity                    0.040496
# Year                               NaN

# %%
heatmap_corr(df_2019,'Score')
heatmap_corr_head(df_2019,'Score')
heatmap_corr_tail(df_2019,'Score')
# Out:
#  These are the correlations for happiness score of all countries in 2019
#
#                                  Score
# GDP per capita                0.793883
# Healthy life expectancy       0.779883
# Social support                0.777058
# Freedom to make life choices  0.566742
# Perceptions of corruption     0.385613
# Generosity                    0.075824
# Year                               NaN
#  These are the correlations for countries with highest happiness score in 2019
#
#                                  Score
# Perceptions of corruption     0.641811
# Freedom to make life choices  0.463460
# Social support                0.160227
# GDP per capita               -0.471811
# Healthy life expectancy      -0.649633
# Generosity                   -0.975396
# Year                               NaN
#  These are the correlations for countries with lowest happiness score 2019
#
#                                      Score
# Freedom to make life choices  0.713216
# Healthy life expectancy       0.662802
# Perceptions of corruption     0.566692
# GDP per capita                0.361163
# Social support                0.342845
# Generosity                    0.154510
# Year                               NaN

# %% [markdown]
# # Some Conclusions

# %% [markdown]
#     According to correlations between happiness scores and other values, we can notice that people who living in happier countries and people who living in sadder countries have different criterias for happiness.
#     In 2015 for people in happier countries, most important criteria is their family. Also in 2015 the most important criteria for  saddest countries is freedom.
#     In 2016 for people in happier countries, most important criteria is confidence intervals, for poeople saddest countries the most important criterias are also confidence intervals and freedom just like 2015.
#     In 2017 for people in happier countries, most important criteria is freedom, for poeople saddest countries the most important criterias are GDP and Healty Life Expectancy.
#     In 2018 for people in happier countries, most important criteria is freedom, for poeople saddest countries the most important criteria is GDP.
#     In 2019 for people in happier countries, most important criteria is Perceptions of corruption, for poeople saddest countries the most important criteria is Freedom to make life choices.

# %%
def lmplot(column_x,column_y,data):
    print("""
    
    Correlation between {} and {} is {}
    
    """.format(column_x,column_y,data.corr()[column_x][column_y]))
    
    sns.lmplot(x = column_x, y = column_y,data = data,palette = 'Paired',hue ='Country')
    
    plt.title(data['Year'].iloc[1])
    
    plt.show()

# %% [markdown]
# # We got a couple of datasets but in this study I will focus on the differences of countries in 2015, different top or bottom countries between 2015-2016 and 2016-2017, also I will chech whether there is a country that has a dramatic change.
# Our goal is analyzing differences between happiest and saddest countries. We will compare them in the plots.

# %%
lmplot('Score','Family',df_2015.head(10))
lmplot('Score','Family',df_2015.tail(10))
# Out:
#
#     Correlation between Score and Family is 0.7306415736200282
#
#     Correlation between Score and Family is 0.6251805353037158

# %%
lmplot('Score','Economy (GDP per Capita)',df_2015.head(10))
lmplot('Score','Economy (GDP per Capita)',df_2015.tail(10))
# Out:
#
#     Correlation between Score and Economy (GDP per Capita) is 0.5258026820758057
#
#     Correlation between Score and Economy (GDP per Capita) is 0.11604571693767232

# %%
lmplot('Score','Freedom',df_2015.head(10))
lmplot('Score','Freedom',df_2015.tail(10))
# Out:
#
#     Correlation between Score and Freedom is 0.2569573049853993
#
#     Correlation between Score and Freedom is 0.40167282520998093

# %% [markdown]
# # Top 10 Country - Health(Expentacy)

# %%
plt.figure(figsize=(25, 10))
sns.barplot(x = 'Country', y = 'Health (Life Expectancy)', data = df_2015.head(10))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Bottom 10 Country - Health(Expentacy)

# %%
plt.figure(figsize=(25, 10))
sns.barplot(x = 'Country', y = 'Trust (Government Corruption)', data = df_2015.tail(10),palette = 'inferno_r')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Top 10 Country - Trust (Government Corruption)

# %%
plt.figure(figsize=(25, 10))
sns.barplot(x = 'Country', y = 'Trust (Government Corruption)', data = df_2015.head(10))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Bottom 10 Country - Trust (Government Corruption)

# %%
plt.figure(figsize=(25, 10))
sns.barplot(x = 'Country', y = 'Trust (Government Corruption)', data = df_2015.tail(10),palette = 'inferno_r')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(25, 10))
sns.barplot(x = 'Country', y = 'Score', data = df_2015.head(10),palette = 'inferno_r')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(25, 10))
sns.barplot(x = 'Country', y = 'Score', data = df_2016.head(10),palette = 'inferno_r')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(25, 10))
sns.barplot(x = 'Country', y = 'Score', data = df_2017.head(10),palette = 'inferno_r')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Northern European countries seem to be in the top positions every year.

# %% [markdown]
# # Now let's look for a dramatic change.

# %%
rename_column(df_2019,'Country or region','Country')

# %%
df_2015_country_score = pd.DataFrame(df_2015[['Score','Country']])
df_2019_country_score = pd.DataFrame(df_2019[['Score','Country']])

# %%
united_df_2015_2019 = df_2015_country_score.merge(df_2019_country_score,how = 'inner',on = 'Country')

# %%
rename_column(united_df_2015_2019,'Score_x','Score_2015')
rename_column(united_df_2015_2019,'Score_y','Score_2019')

# %%
united_df_2015_2019['Difference_Between_Scores_In_4_Years'] = united_df_2015_2019['Score_2019']-united_df_2015_2019['Score_2015']

# %% [markdown]
# # The countries that have most dramatic rise in 4 years.

# %%
plt.figure(figsize=(25, 10))
sns.barplot(x = 'Country',y = 'Difference_Between_Scores_In_4_Years',data = united_df_2015_2019.sort_values(ascending = False,by = 'Difference_Between_Scores_In_4_Years').head(10),palette = 'gist_rainbow')
plt.xticks(rotation = 90)
plt.show()

# %%
united_df_2015_2019.sort_values(ascending = False,by = 'Difference_Between_Scores_In_4_Years').head(10)
# Out:
#           Country  Score_2015  Score_2019  \
# 145         Benin       3.340       4.883
# 141   Ivory Coast       3.655       4.944
# 148          Togo       2.839       4.085
# 98       Honduras       4.788       5.860
# 142  Burkina Faso       3.587       4.587
# 97        Hungary       4.800       5.758
# 81        Romania       5.124       6.070
# 133         Gabon       3.896       4.799
# 135      Cambodia       3.819       4.700
# 140        Guinea       3.656       4.534
#
#      Difference_Between_Scores_In_4_Years
# 145                                 1.543
# 141                                 1.289
# 148                                 1.246
# 98                                  1.072
# 142                                 1.000
# 97                                  0.958
# 81                                  0.946
# 133                                 0.903
# 135                                 0.881
# 140                                 0.878

# %% [markdown]
# # The countries that have most dramatic fall in 4 years.

# %%
plt.figure(figsize=(25, 10))
sns.barplot(x = 'Country',y = 'Difference_Between_Scores_In_4_Years',data = united_df_2015_2019.sort_values(ascending = False,by = 'Difference_Between_Scores_In_4_Years').tail(10),palette = 'flare_r')
plt.xticks(rotation = 90)
plt.show()

# %%
united_df_2015_2019.sort_values(ascending = False,by = 'Difference_Between_Scores_In_4_Years').tail(10)
# Out:
#        Country  Score_2015  Score_2019  Difference_Between_Scores_In_4_Years
# 94   Swaziland       4.867       4.212                                -0.655
# 15      Brazil       6.983       6.300                                -0.683
# 127      Yemen       4.077       3.380                                -0.697
# 119   Botswana       4.332       3.488                                -0.844
# 122     Malawi       4.292       3.410                                -0.882
# 111      Haiti       4.518       3.597                                -0.921
# 108   Zimbabwe       4.610       3.663                                -0.947
# 80      Zambia       5.129       4.107                                -1.022
# 90     Lesotho       4.898       3.802                                -1.096
# 21   Venezuela       6.810       4.707                                -2.103

# %% [markdown]
# # Now let's build the model

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
df_2015['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
le = LabelEncoder()
df_2015['Region'] = le.fit_transform(df_2015['Region'])

# %%
X = df_2015.drop(['Country','Year','Score'],axis = 1)
y = df_2015['Score']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

# %%
xgb = XGBRegressor()
lr = LinearRegression()
tre = DecisionTreeRegressor()
forest = RandomForestRegressor(n_estimators=10)
grad = GradientBoostingRegressor()
ada = AdaBoostRegressor()
kn = KNeighborsRegressor()

# %%
models = [xgb,lr,tre,forest,grad,ada,kn]

# %% [markdown]
# We got a few models so we put all of them in a loop to work fast.

# %%
for model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    score = model.score(X_test,y_test)
    print(model)
    print(score)
    print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
    print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
    print('R2 Score:', r2_score(y_test, y_pred))
    print('---------------------------------------------------')
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)
# 0.90637697189421
# Mean Squared Error: 0.1243565260901004
# Root Mean Squared Error: 0.3526422069039672
# Mean Absolute Error: 0.2708851199959809
# R2 Score: 0.90637697189421
# ---------------------------------------------------
# LinearRegression()
# 0.9141864103251915
# Mean Squared Error: 0.11398349443709692
# Root Mean Squared Error: 0.3376144168087271
# Mean Absolute Error: 0.28653753907716567
# R2 Score: 0.9141864103251915
# ---------------------------------------------------
# DecisionTreeRegressor()
# 0.609124217192726
# Mean Squared Error: 0.5191880188679248
# Root Mean Squared Error: 0.7205470275200119
# Mean Absolute Error: 0.6073773584905661
# R2 Score: 0.609124217192726
# ---------------------------------------------------
# RandomForestRegressor(n_estimators=10)
# 0.8904129908944066
# Mean Squared Error: 0.14556098037735846
# Root Mean Squared Error: 0.38152454754230225
# Mean Absolute Error: 0.29748301886792455
# R2 Score: 0.8904129908944066
# ---------------------------------------------------
# GradientBoostingRegressor()
# 0.8938625190577304
# Mean Squared Error: 0.14097908052088093
# Root Mean Squared Error: 0.37547181055424245
# Mean Absolute Error: 0.3090797965898468
# R2 Score: 0.8938625190577304
# ---------------------------------------------------
# AdaBoostRegressor()
# 0.8628437941618431
# Mean Squared Error: 0.1821802780236832
# Root Mean Squared Error: 0.42682581696013094
# Mean Absolute Error: 0.3477770554215364
# R2 Score: 0.8628437941618431
# ---------------------------------------------------
# KNeighborsRegressor()
# 0.8605815774175936
# Mean Squared Error: 0.18518510943396227
# Root Mean Squared Error: 0.43033139489695876
# Mean Absolute Error: 0.3547320754716981
# R2 Score: 0.8605815774175936
# ---------------------------------------------------

# %% [markdown]
# We can say that LinearRegression method has slightly better score. Now let's check.

# %%
lr.fit(X_train,y_train)
lr_pred = lr.predict(X_test)
lr_score = lr.score(X_test,y_test)

# %%
plt.figure(figsize=(10, 5))
plt.scatter(y_test, y_pred, color='red')
plt.plot(y_test, y_test, color='green')
plt.xlabel('True')
plt.ylabel('Predict')
plt.title('Linear Regression')
plt.show()

# %% [markdown]
# Finally we try the model with real data values. Let's consider Turkey.

# %%
df_2015[df_2015['Country']=='Turkey']
# Out:
#    Country  Region  Standard Error  Economy (GDP per Capita)   Family  \
# 75  Turkey       4         0.03864                   1.06098  0.94632
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 75                   0.73172  0.22815                        0.15746
#
#     Generosity  Dystopia Residual  Year  Score
# 75     0.12253            2.08528  2015  5.332

# %%
input_data = [4,0.03864,1.06098,0.94632,0.73172,0.22815,0.15746,0.12253,2.08528]
input_data_as_array = np.asarray(input_data)
input_data_as_array_reshaped = input_data_as_array.reshape(1,-1)
input_ = scaler.transform(input_data_as_array_reshaped)
lr_fit = lr.fit(X_train,y_train)
pred = lr_fit.predict(input_)

# %%
print("""
Our real data score for Turkey is {}

Predict of our model is {}

""".format(df_2015[df_2015['Country']=='Turkey']['Score'].values,pred))
# Out:
# Our real data score for Turkey is [5.332]
#
# Predict of our model is [5.31407151]

# %% [markdown]
# # It looks like our model is successfull

# %% [markdown]
# # Let's try cross validation to reaching best possible score on our model.

# %%
from sklearn.model_selection import cross_val_score

# %%
score_on_train = cross_val_score(lr_fit,X_train,y_train,scoring = 'r2',cv = 5)
score_on_test = cross_val_score(lr_fit,X_test,y_test,scoring = 'r2',cv = 5)

# %%
score_on_test
# Out:
# array([0.9999999 , 0.99999991, 0.99999996, 0.99999989, 0.99999991])

# %%
score_on_train
# Out:
# array([0.99999993, 0.99999984, 0.99999993, 0.99999992, 0.99999991])

# %% [markdown]
# # With Cross Validation, out score became nearly perfect.

# %% [markdown]
# # Conclusions

# %% [markdown]
# As a result, different countries have different criteria for happiness score. In this study, we saw that the happiest countries and the relatively unhappiest countries have different lifestyles and happiness criteria. In the correlations made for each year, we saw that the happiness criteria changed from year by year. We can say that the samples that decide on the criteria of the research change because the happiness criteria all over the world cannot be changed from year to year. The sample must be selected and stay constant in order to make better analyzes in the future.
